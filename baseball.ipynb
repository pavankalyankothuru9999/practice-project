# %% [markdown]
# # Data Importing

# %%
# importing the all the libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams["figure.figsize"] = (20,10)
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading the dataset to be solved
df= pd.read_csv(r'C:\Users\pavan\OneDrive\Documents\question papers upsc\baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Displaying the top five rows using head keyword
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # EDA

# %%
#Check if any Column's has NA or Missing Values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values as its showing zero null values

# %%
#Shape of the Data
df.shape
# Out:
# (30, 17)

# %%
# finding the Data Types of Columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# Descriptive statistics of data
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# applying the distribution plot
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=17 :
        ax= plt.subplot(5,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here we can observe the each distribution plot that all are almost normally distributed and are not skewed

# %%
#applying the box plot
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=17 :
        ax= plt.subplot(5,4,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here using the box plot we can observe there are only very little outliers and we can ignore them

# %%
#applying the correlation
df_corr = df.corr().abs()

plt.figure(figsize=(22,16))
sns.heatmap(df_corr, vmin=-1, vmax=1, annot=True,
           square=True, center=0, fmt='.2g', linewidths=.1,)
plt.tight_layout()

# %% [markdown]
# Here by applying the correlation we can see may features are dependent on other features.
#
# In detail we can find the multi colinearity by using variance inflation factor

# %%
X=df.drop(columns=['W'],axis=1)
y=df['W']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaler=scaler.fit_transform(X)

vif=pd.DataFrame()
vif['score'] = [variance_inflation_factor(X_scaler,i) for i in range(X_scaler.shape[1])]
vif['feature'] = X.columns
vif
# Out:
#           score feature
# 0     11.522370       R
# 1     13.311532      AB
# 2     10.070668       H
# 3      4.019297      2B
# 4      3.294146      3B
# 5     10.079902      HR
# 6      3.806098      BB
# 7      2.652401      SO
# 8      2.102684      SB
# 9    191.839155      RA
# 10  1680.387145      ER
# 11  1222.722240     ERA
# 12     3.059904      CG
# 13     3.654331     SHO
# 14     5.798850      SV
# 15     2.186219       E

# %% [markdown]
# from the above results we can confirm that there are many features dependent on each other.
#
# (HR and R) and (AB and H) and ERA,ER,RA are dependent so by droping HR,AB,ER,RA we can get the desired results.

# %%
X=df.drop(columns=['W','HR','AB','ER','RA'],axis=1)
y=df['W']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaler=scaler.fit_transform(X)

vif=pd.DataFrame()
vif['score'] = [variance_inflation_factor(X_scaler,i) for i in range(X_scaler.shape[1])]
vif['feature'] = X.columns
vif
# Out:
#        score feature
# 0   2.538504       R
# 1   3.565922       H
# 2   3.289128      2B
# 3   2.673120      3B
# 4   3.095941      BB
# 5   1.531462      SO
# 6   1.752281      SB
# 7   4.602492     ERA
# 8   2.150722      CG
# 9   3.123269     SHO
# 10  2.539772      SV
# 11  1.179726       E

# %% [markdown]
# We can see from above results ,by droping those features we got the desired results.

# %%
X
# Out:
#       R     H   2B  3B   BB    SO   SB   ERA  CG  SHO  SV    E
# 0   724  1497  300  42  383   973  104  3.73   2    8  56   88
# 1   696  1349  277  44  439  1264   70  4.07   2   12  45   86
# 2   669  1395  303  29  533  1157   86  3.67  11   10  38   79
# 3   622  1381  260  27  404  1231   68  3.98   7    9  37  101
# 4   689  1515  289  49  455  1259   83  4.64   7   12  35   86
# 5   891  1480  308  17  570  1151   88  3.80   7   10  34   88
# 6   764  1397  272  19  554  1227   63  4.03   3    4  48   93
# 7   713  1370  246  20  418  1331   44  4.05   0   10  43   77
# 8   644  1383  278  32  436  1310   87  3.74   1   12  60   95
# 9   748  1495  294  33  478  1148   71  4.31   3   10  40   97
# 10  751  1419  279  32  503  1233  101  4.24   5    9  45  119
# 11  729  1363  278  26  486  1392  121  3.57   5   13  39   85
# 12  661  1331  243  21  435  1150   52  3.94   2   12  46   93
# 13  656  1379  262  22  478  1336   69  4.16   6   12  45   94
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# # Feature extraction

# %%
#importing ML models from scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# spliting the dataset into train and test 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25)

# %%
# passing all the models
regressors = {
    'Linear Regression' : LinearRegression(),
    'Decision Tree' : DecisionTreeRegressor(),
    'Random Forest' : RandomForestRegressor(),
    'Support Vector Machines' : SVR(gamma=1),
    'K-nearest Neighbors' : KNeighborsRegressor(n_neighbors=1)
}
results=pd.DataFrame(columns=['MAE','MSE','R2-score'])
for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.round(r2_score(y_test,pred),3)
                         ]

# %%
results
# Out:
#                             MAE      MSE  R2-score
# Linear Regression         1.740    4.096     0.924
# Decision Tree             9.000  127.500    -1.373
# Random Forest             4.750   31.588     0.412
# Support Vector Machines  10.150  140.690    -1.618
# K-nearest Neighbors       8.125   90.875    -0.691

# %%
results.sort_values('R2-score',ascending=False).style.background_gradient(cmap='Greens',subset=['R2-score'])
# Out:
# <style  type="text/css" >
# #T_3ce7855a_f08a_11eb_a87b_5cbaef99ed1crow0_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_3ce7855a_f08a_11eb_a87b_5cbaef99ed1crow1_col2{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_3ce7855a_f08a_11eb_a87b_5cbaef99ed1crow2_col2{
#             background-color:  #a4da9e;
#             color:  #000000;
#         }#T_3ce7855a_f08a_11eb_a87b_5cbaef99ed1crow3_col2{
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }#T_3ce7855a_f08a_11eb_a87b_5cbaef99ed1crow4_col2{
#             background-color:  #f7fcf5;
#             color:  #000000;
# ...

# %% [markdown]
# from the above results we can clearly say the best is LinearRegression

# %% [markdown]
# # Saving model

# %%
# Saving the model using pickle
import pickle

# %%
# Dumping the model for future use
with open('model_pickle','wb') as f:
    pickle.dump(results,f)

# %%
# Loading the model for future use
with open('model_pickle','rb') as f:
    mp = pickle.load(f)
