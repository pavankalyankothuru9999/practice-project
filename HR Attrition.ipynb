# %% [markdown]
# # Data Loading

# %%
# importing the all the libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams["figure.figsize"] = (20,10)
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading the dataset to be solved
df= pd.read_csv(r'C:\Users\pavan\OneDrive\Documents\question papers upsc\HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# Displaying the top five rows using head keyword
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
#Check if any Column's has NA or Missing Values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# There are no null values as its showing zero null values

# %%
#Shape of the Data
df.shape
# Out:
# (1470, 35)

# %%
# finding the Data Types of Columns
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
#To get to know how much % of employees left the organization
df.Attrition.value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %% [markdown]
# 84% of the people doesnot leave the company and only 16% of people left the company. By seeing this data we can clearly say that this is imblanced data.

# %% [markdown]
# # EDA

# %%
#ploting the barplot of employee turnover vs count
Attrition=df.Attrition.value_counts()
sns.barplot(x=Attrition.index ,y=Attrition.values)
plt.title('Distribution of Employee Turnover')
plt.xlabel('Employee Turnover', fontsize=16)
plt.ylabel('Count', fontsize=16)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# here we can see the barplot of the employees leaving and not leaving the company ie 16% and 84% respectively

# %%
fig=plt.figure(figsize=(15,8))
value=df['YearsAtCompany']<11
df3=df[value]
sns.countplot(x='YearsAtCompany',hue='Attrition',data=df3)
plt.show()

# %% [markdown]
# Conclusion:
#
# Employee leaving the company at initial stage

# %%
fig=plt.figure(figsize=(10,6))
sns.countplot(x='YearsWithCurrManager',hue='Attrition',data=df,color='black')
plt.show()

# %% [markdown]
# Employee YearsSinceLastPromotion vs Attrition

# %%
fig=plt.figure(figsize=(10,6))
sns.countplot(x='YearsSinceLastPromotion',hue='Attrition',data=df,color='green')
plt.show()

# %% [markdown]
# Analysis of parameter vs Attrition

# %%
#ploting the distribution plot of age
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# Age is fairly normally distributed with average Age around 35. Most of the employees in the range 25 to 45

# %%
#ploting the distribution plot of monthly income
sns.distplot(df['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %% [markdown]
# Most the employees have their monthly income around 5000$ and is distribution Rightly Skewed

# %%
#ploting the distribution plot of total working years
sns.distplot(df['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %% [markdown]
# Total Working Years is also right skewed similar to Age

# %%
#Method that plot density plots on the columns passed as input
def kdePlot(var):
    fig = plt.figure(figsize=(15,4))
    ax=sns.kdeplot(df.loc[(df['Attrition'] == 'No'),var] , color='b',shade=True, label='no Attrition') 
    ax=sns.kdeplot(df.loc[(df['Attrition'] == 'Yes'),var] , color='r',shade=True, label='Attrition')
    plt.title('Employee Attrition with respect to {}'.format(var))

# %%
numerical_df=df.select_dtypes(include=np.number)
numeric_cols_kdeplot=list(numerical_df.columns)
remove_columns=['Age','DistanceFromHome','Education','EmployeeCount','EmployeeNumber',
'EnvironmentSatisfaction' ,'HourlyRate','JobInvolvement','JobSatisfaction','MonthlyRate','NumCompaniesWorked',
'PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears',
'TrainingTimesLastYear','WorkLifeBalance','YearsSinceLastPromotion']
for l in remove_columns:
    numeric_cols_kdeplot.remove(l)

# %%
#Plotting KDE plots
for n in numeric_cols_kdeplot:
    kdePlot(n)

# %% [markdown]
# Observations
#
# Attrition is high with Employees having joblevel as 1.
#
# Employees whose monthly income is below $5000 have high attrition.
#
# Employees who worked in the company around 0 to 1 years have high attrition.
#
# Employees who are in current role for around 0 to 4 years have high attrition.

# %%
BarPlot_columns=['Age','DistanceFromHome','EducationField',
                'JobInvolvement','JobLevel','JobRole','OverTime','TotalWorkingYears','TrainingTimesLastYear',
                'WorkLifeBalance','YearsInCurrentRole']

# %%
#Method the perform Bar plots
def Bar_plots(var):
    col=pd.crosstab(df[var],df.Attrition)
    col.div(col.sum(1).astype(float), axis=0).plot(kind="bar", stacked=False, figsize=(8,4))
    plt.xticks(rotation=90)

# %%
for col in BarPlot_columns:
    Bar_plots(col)

# %% [markdown]
# Observations
#
# Attrition is very high with employees having age in between 18 to 22. These might be due to students who are doing intership or small contract jobs
#
# Attrition is more when the distance of office is more from home
#
# Attrition is high with employee's education in the field of Human Resources, Marketing and Technical Degree that other fields
#
# Attrition is high with employee's whose job role is in the field of Human Resources, Sales Representative, Laboratory Technician.
#
# Employees who work over time have high attrition than employees who did not do over time
#
# Employees who are working less than 2 years have more attrition

# %%
#Replacing Yes with 1 and No with 0 in Attrition Column
df['Attrition']=np.where(df['Attrition']=='No', #condition
                 0, #value if condition is true
                 1)

# %%
#describing the values upto 20 columns
df.describe().iloc[:,:20]
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# std              0.0      602.024335                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      491.250000                 2.000000    48.000000
# 50%              1.0     1020.500000                 3.000000    66.000000
# 75%              1.0     1555.750000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement     JobLevel  JobSatisfaction  MonthlyIncome  \
# count     1470.000000  1470.000000      1470.000000    1470.000000
# mean         2.729932     2.063946         2.728571    6502.931293
# std          0.711561     1.106940         1.102846    4707.956783
# min          1.000000     1.000000         1.000000    1009.000000
# 25%          2.000000     1.000000         2.000000    2911.000000
# 50%          3.000000     2.000000         3.000000    4919.000000
# 75%          3.000000     3.000000         4.000000    8379.000000
# max          4.000000     5.000000         4.000000   19999.000000
#
#         MonthlyRate  NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# count   1470.000000         1470.000000        1470.000000        1470.000000
# mean   14313.103401            2.693197          15.209524           3.153741
# std     7117.786044            2.498009           3.659938           0.360824
# min     2094.000000            0.000000          11.000000           3.000000
# 25%     8047.000000            1.000000          12.000000           3.000000
# 50%    14235.500000            2.000000          14.000000           3.000000
# 75%    20461.500000            4.000000          18.000000           3.000000
# max    26999.000000            9.000000          25.000000           4.000000
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel
# count               1470.000000         1470.0       1470.000000
# mean                   2.712245           80.0          0.793878
# std                    1.081209            0.0          0.852077
# min                    1.000000           80.0          0.000000
# 25%                    2.000000           80.0          0.000000
# 50%                    3.000000           80.0          1.000000
# 75%                    4.000000           80.0          1.000000
# max                    4.000000           80.0          3.000000

# %%
# employee count
df.EmployeeCount.value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
# standard hours
df.StandardHours.value_counts()
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %%
len(set(df.EmployeeNumber))
# Out:
# 1470

# %% [markdown]
# Dropping the columns EmployeeCount,StandardHours,EmployeeNumber as these columns does not help in model building.

# %%
# droping the three umimport columns
df=df.drop(['EmployeeCount', 'StandardHours','EmployeeNumber'], axis=1)

# %%
# finding the mean of first 20 columns
df.groupby('Attrition').mean().iloc[:,:20]
# Out:
#                  Age   DailyRate  DistanceFromHome  Education  \
# Attrition
# 0          37.561233  812.504461          8.915653   2.927007
# 1          33.607595  750.362869         10.632911   2.839662
#
#            EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# Attrition
# 0                         2.771290   65.952149        2.770479  2.145985
# 1                         2.464135   65.573840        2.518987  1.637131
#
#            JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# Attrition
# 0                 2.778589    6832.739659  14265.779400            2.645580
# 1                 2.468354    4787.092827  14559.308017            2.940928
#
#            PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# Attrition
# 0                  15.231144           3.153285                  2.733982
# 1                  15.097046           3.156118                  2.599156
#
#            StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# Attrition
# 0                  0.845093          11.862936               2.832928
# 1                  0.527426           8.244726               2.624473
#
#            WorkLifeBalance  YearsAtCompany
# Attrition
# 0                 2.781022        7.369019
# 1                 2.658228        5.130802

# %%
# finding the mean of last 6 columns
df.groupby('Attrition').mean().iloc[:,20:26]
# Out:
#            YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# Attrition
# 0                    4.484185                 2.234388              4.367397
# 1                    2.902954                 1.945148              2.852321

# %%
# finding the correlation and ploting a heat map of that correlation matrix
corr_matrix = df.corr()
f , ax = plt.subplots(figsize=(20,12))
sns.heatmap(corr_matrix,vmax=0.8, annot=True)
# Out:
# <AxesSubplot:>

# %%
# seperating the numerical and categorical values
num_df=df.select_dtypes(include=np.number)
cat_df=df.select_dtypes(exclude=np.number)
num_cols=list(num_df.columns)
cat_cols=list(cat_df.columns)

# %%
# applying the for loop for finding the relationship between each column and attrition rate
for n in cat_cols:
    print(pd.crosstab(df['Attrition'],df[n],normalize='columns'))
# Out:
# BusinessTravel  Non-Travel  Travel_Frequently  Travel_Rarely
# Attrition
# 0                     0.92           0.750903       0.850431
# 1                     0.08           0.249097       0.149569
# Department  Human Resources  Research & Development     Sales
# Attrition
# 0                  0.809524                0.861602  0.793722
# 1                  0.190476                0.138398  0.206278
# EducationField  Human Resources  Life Sciences  Marketing   Medical     Other  \
# Attrition
# 0                      0.740741       0.853135   0.779874  0.864224  0.865854
# 1                      0.259259       0.146865   0.220126  0.135776  0.134146
#
# EducationField  Technical Degree
# Attrition
# 0                       0.757576
# 1                       0.242424
# Gender       Female      Male
# Attrition
# 0          0.852041  0.829932
# 1          0.147959  0.170068
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Attrition
# 0                           0.931298         0.769231               0.760618
# 1                           0.068702         0.230769               0.239382
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# Attrition
# 0          0.95098                0.931034              0.975
# 1          0.04902                0.068966              0.025
#
# JobRole    Research Scientist  Sales Executive  Sales Representative
# Attrition
# 0                    0.839041         0.825153               0.60241
# 1                    0.160959         0.174847               0.39759
# MaritalStatus  Divorced   Married    Single
# Attrition
# 0              0.899083  0.875186  0.744681
# 1              0.100917  0.124814  0.255319
# Over18            Y
# Attrition
# 0          0.838776
# 1          0.161224
# OverTime         No       Yes
# Attrition
# 0          0.895636  0.694712
# 1          0.104364  0.305288

# %%
# getting the dummy variables for all the categorical values
cat_df_dummies=pd.get_dummies(df[cat_cols],drop_first=True)
final_df=pd.concat([cat_df_dummies,num_df],axis=1)

# %%
final_df.head()
# Out:
#    BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                                 0                             1
# 1                                 1                             0
# 2                                 0                             1
# 3                                 1                             0
# 4                                 0                             1
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 1                                  1                 0
# 2                                  1                 0
# 3                                  1                 0
# 4                                  1                 0
#
#    EducationField_Life Sciences  EducationField_Marketing  \
# 0                             1                         0
# 1                             1                         0
# 2                             0                         0
# 3                             1                         0
# 4                             0                         0
#
#    EducationField_Medical  EducationField_Other  \
# 0                       0                     0
# 1                       0                     0
# 2                       0                     1
# 3                       0                     0
# 4                       1                     0
#
#    EducationField_Technical Degree  Gender_Male  ...  PerformanceRating  \
# 0                                0            0  ...                  3
# 1                                0            1  ...                  4
# 2                                0            1  ...                  3
# 3                                0            0  ...                  3
# 4                                0            1  ...                  3
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
# 2                         2                 0                  7
# 3                         3                 0                  8
# 4                         4                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1               6                   4
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
#
# [5 rows x 45 columns]

# %%
y=final_df.Attrition
X=final_df.drop(['Attrition'], axis=1)

# %% [markdown]
# # Feature extraction

# %%
#Splitting Data in Train and Test Set
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score,roc_auc_score,precision_recall_curve,confusion_matrix,precision_score,confusion_matrix
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
#Building base model(Predicting that no employee leaves the company)
base=np.zeros(1470)
print(accuracy_score(base,df.Attrition))
# Out:
# 0.8387755102040816

# %% [markdown]
# Base model has 83.8% accuracy. Thus accuracy is not best criteria to check the performance of the model

# %%
#Method that applies model on the data and Predict the attrition
def model(mod,model_name,x_tr,y_tr,x_tes,y_te):
    mod.fit(x_tr,y_tr)
    pred_dt=mod.predict(x_tes)
    print("     ",model_name,"      ")
    print("Accuracy ",accuracy_score(pred_dt,y_te))
    print("ROC_AUC  ",roc_auc_score(pred_dt,y_te))
    cm=confusion_matrix(pred_dt,y_te)
    print("Confusion Matrix  \n",cm)
    print("                    Classification Report \n",classification_report(pred_dt,y_te))

# %%
# applying the logistic regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
model(lr,"Logistic Regression",X_train,y_train,X_test,y_test)
# Out:
#       Logistic Regression
# Accuracy  0.8435374149659864
# ROC_AUC   0.9215017064846416
# Confusion Matrix
#  [[247  46]
#  [  0   1]]
#                     Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91       293
#            1       0.02      1.00      0.04         1
#
#     accuracy                           0.84       294
#    macro avg       0.51      0.92      0.48       294
# weighted avg       1.00      0.84      0.91       294

# %% [markdown]
# Accuracy is 84% but Precision and Recall for class 1 is low because  the data is imbalanced

# %%
# applying the decision tree  classifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(min_samples_leaf=20, max_depth=4)
model(dt,"Decision Tree",X_train,y_train,X_test,y_test)
# Out:
#       Decision Tree
# Accuracy  0.8503401360544217
# ROC_AUC   0.7186617100371747
# Confusion Matrix
#  [[236  33]
#  [ 11  14]]
#                     Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      0.88      0.91       269
#            1       0.30      0.56      0.39        25
#
#     accuracy                           0.85       294
#    macro avg       0.63      0.72      0.65       294
# weighted avg       0.90      0.85      0.87       294

# %% [markdown]
# Accuracy is 85% but again Precision and Recall for class 1 is low

# %%
# applying the random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10,max_depth=4)
model(rf,"Random Forest",X_train,y_train,X_test,y_test)
# Out:
#       Random Forest
# Accuracy  0.8401360544217688
# ROC_AUC   0.6724137931034483
# Confusion Matrix
#  [[245  45]
#  [  2   2]]
#                     Classification Report
#                precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91       290
#            1       0.04      0.50      0.08         4
#
#     accuracy                           0.84       294
#    macro avg       0.52      0.67      0.50       294
# weighted avg       0.98      0.84      0.90       294

# %% [markdown]
# Accuracy is 85% but even though recall is better ,Precision is low for class 1

# %% [markdown]
# Due to Class Imbalance problem model is not able to make predictions on class 1(Attrition Yes)

# %%
#Performing OverSample using SMOTE(Synthetic Minority Over Sampling Technique)
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
X_sm, y_sm=smote.fit_resample(X,y)

# %%
X_train_sm,X_test_sm,y_train_sm,y_test_sm=train_test_split(X_sm,y_sm,test_size=0.2,random_state=100)

# %%
#logistic Regression for OverSampled Data 
lr_sm=LogisticRegression()
model(lr_sm,"Logistic Regression",X_train_sm,y_train_sm,X_test_sm,y_test_sm)
# Out:
#       Logistic Regression
# Accuracy  0.7145748987854251
# ROC_AUC   0.715001313887794
# Confusion Matrix
#  [[171  65]
#  [ 76 182]]
#                     Classification Report
#                precision    recall  f1-score   support
#
#            0       0.69      0.72      0.71       236
#            1       0.74      0.71      0.72       258
#
#     accuracy                           0.71       494
#    macro avg       0.71      0.72      0.71       494
# weighted avg       0.72      0.71      0.71       494

# %% [markdown]
# Accuracy is 70%(less than the model with original data set) but Precision and Recall for class 1 is improved

# %%
dt_sm=DecisionTreeClassifier(min_samples_leaf=20, max_depth=4)
model(dt_sm,"Decision Tree",X_train_sm,y_train_sm,X_test_sm,y_test_sm)
# Out:
#       Decision Tree
# Accuracy  0.7793522267206477
# ROC_AUC   0.7806818181818183
# Confusion Matrix
#  [[184  46]
#  [ 63 201]]
#                     Classification Report
#                precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       230
#            1       0.81      0.76      0.79       264
#
#     accuracy                           0.78       494
#    macro avg       0.78      0.78      0.78       494
# weighted avg       0.78      0.78      0.78       494

# %% [markdown]
# Accuracy is 78% but Precision and Recall for class 1 is improved

# %%
rf_sm=RandomForestClassifier(n_estimators=10,max_depth=4)
model(rf_sm,"Random Forest",X_train_sm,y_train_sm,X_test_sm,y_test_sm)
# Out:
#       Random Forest
# Accuracy  0.8846153846153846
# ROC_AUC   0.884672131147541
# Confusion Matrix
#  [[220  30]
#  [ 27 217]]
#                     Classification Report
#                precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89       250
#            1       0.88      0.89      0.88       244
#
#     accuracy                           0.88       494
#    macro avg       0.88      0.88      0.88       494
# weighted avg       0.88      0.88      0.88       494

# %% [markdown]
# Accuracy is high and Precision and Recall for class 1 is also High

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# from all the models randomforestclassifer is giving the best so we are doing hyperparameter tuning for randomforest only

# %%
# import randomizedsearchcv for selecting the parameters
from sklearn.model_selection import RandomizedSearchCV

# %%
# giving all the parameters
params={'n_estimators':[100, 300, 500, 700],
        'min_samples_split':[1,2,3,4],
        'min_samples_leaf':[1,2,3,4],
            'max_depth':[None,1,2,3,4,5,6,7,8]}

# %%
# passing all the parameters 
g=RandomizedSearchCV(RandomForestClassifier(),params,cv=10)

# %%
# fitting the model
g.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [None, 1, 2, 3, 4, 5, 6, 7,
#                                                       8],
#                                         'min_samples_leaf': [1, 2, 3, 4],
#                                         'min_samples_split': [1, 2, 3, 4],
#                                         'n_estimators': [100, 300, 500, 700]})

# %%
# printing the best estimator, best parameters, best score
print(g.best_estimator_)
print(g.best_params_)
print(g.best_score_)
# Out:
# RandomForestClassifier(max_depth=4, min_samples_leaf=4, n_estimators=500)
# {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 4}
# 0.8494712443864986

# %%
# importing the cross validation 
from sklearn.model_selection import cross_val_score

# %%
# fiting the model
rf_sm=RandomForestClassifier(max_depth= None, min_samples_leaf=4, min_samples_split=2,n_estimators=500)
model(rf_sm,"Random Forest",X_train_sm,y_train_sm,X_test_sm,y_test_sm)
# Out:
#       Random Forest
# Accuracy  0.9311740890688259
# ROC_AUC   0.9314286651468683
# Confusion Matrix
#  [[233  20]
#  [ 14 227]]
#                     Classification Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       253
#            1       0.92      0.94      0.93       241
#
#     accuracy                           0.93       494
#    macro avg       0.93      0.93      0.93       494
# weighted avg       0.93      0.93      0.93       494

# %%
print('Mean of cross validaton Score is',np.round(np.mean(score)*100,3))
# Out:
# Mean of cross validaton Score is 85.578

# %% [markdown]
# # Model Saving

# %%
# Saving the model using pickle
import pickle

# %%
# Dumping the model for future use
with open('model_pickle','wb') as f:`
    pickle.dump(model,f)

# %%
# Loading the model for future use
with open('model_pickle','rb') as f:
    mp = pickle.load(f)
