# %%
# importing the all the libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams["figure.figsize"] = (20,10)
import warnings
warnings.filterwarnings("ignore")

# %%
#loading the csv dataset using pandas
df= pd.read_csv(r'C:\Users\pavan\OneDrive\Documents\question papers upsc\book1.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#changing the column names
df.columns=['Country','Region','Happiness_rank','Happiness_score','Standard_error','Economy','Family','Health',
            'Freedom','Trust','Generosity','Dystopia_residual']

# %%
#calling the first five rows
df.head()
# Out:
#        Country          Region  Happiness_rank  Happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard_error  Economy   Family   Health  Freedom    Trust  Generosity  \
# 0         0.03411  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    Dystopia_residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# ...

# %%
#finding the shape of dataset
df.shape
# Out:
# (158, 12)

# %%
#finding the info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            158 non-null    object
#  1   Region             158 non-null    object
#  2   Happiness_rank     158 non-null    int64
#  3   Happiness_score    158 non-null    float64
#  4   Standard_error     158 non-null    float64
#  5   Economy            158 non-null    float64
#  6   Family             158 non-null    float64
#  7   Health             158 non-null    float64
#  8   Freedom            158 non-null    float64
#  9   Trust              158 non-null    float64
#  10  Generosity         158 non-null    float64
#  11  Dystopia_residual  158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
#finding is there any null values. there are zero null values
df.isnull().sum()
# Out:
# Country              0
# Region               0
# Happiness_rank       0
# Happiness_score      0
# Standard_error       0
# Economy              0
# Family               0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia_residual    0
# dtype: int64

# %%
#here we describe all the mean max count and everything
df.describe()
# Out:
#        Happiness_rank  Happiness_score  Standard_error     Economy  \
# count      158.000000       158.000000      158.000000  158.000000
# mean        79.493671         5.375734        0.047885    0.846137
# std         45.754363         1.145010        0.017146    0.403121
# min          1.000000         2.839000        0.018480    0.000000
# 25%         40.250000         4.526000        0.037268    0.545808
# 50%         79.500000         5.232500        0.043940    0.910245
# 75%        118.750000         6.243750        0.052300    1.158448
# max        158.000000         7.587000        0.136930    1.690420
#
#            Family      Health     Freedom       Trust  Generosity  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean     0.991046    0.630259    0.428615    0.143422    0.237296
# std      0.272369    0.247078    0.150693    0.120034    0.126685
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
# we are seeing the relationship of all features using hist plot
df[['Happiness_score','Standard_error','Economy','Family','Health',
            'Freedom','Trust','Generosity','Dystopia_residual']].hist(figsize=(18,12), bins=50, grid=False);

# %%
# using the corr() to find the correlation 
df.corr()
# Out:
#                    Happiness_rank  Happiness_score  Standard_error   Economy  \
# Happiness_rank           1.000000        -0.992105        0.158516 -0.785267
# Happiness_score         -0.992105         1.000000       -0.177254  0.780966
# Standard_error           0.158516        -0.177254        1.000000 -0.217651
# Economy                 -0.785267         0.780966       -0.217651  1.000000
# Family                  -0.733644         0.740605       -0.120728  0.645299
# Health                  -0.735613         0.724200       -0.310287  0.816478
# Freedom                 -0.556886         0.568211       -0.129773  0.370300
# Trust                   -0.372315         0.395199       -0.178325  0.307885
# Generosity              -0.160142         0.180319       -0.088439 -0.010465
# Dystopia_residual       -0.521999         0.530474        0.083981  0.040059
#
#                      Family    Health   Freedom     Trust  Generosity  \
# ...

# %%
# using the heatmap we can find the relation between each feature
f,ax = plt.subplots(figsize = (15,15))
sns.heatmap(df.corr(), annot = True, linewidth = 0.5, fmt='.2f', ax=ax)
plt.show()

# %%
# here we find the relation between happiness_score and economy using plot 
import matplotlib.pyplot as plt
plt.plot(df['Happiness_score'],df['Economy'])
plt.title('Happiness_score vs Economy')
plt.xlabel('Happiness_score')
plt.ylabel('Economy')
plt.show()

# %%
# here we find the relation between happiness_score and family using plot
plt.plot(df['Happiness_score'],df['Family'])
plt.title('Happiness_score vs Family')
plt.xlabel('Happiness_score')
plt.ylabel('Family')
plt.show()

# %%
# we are finding the mean of happiness_score of each region
df.groupby('Region')['Happiness_score'].mean()
# Out:
# Region
# Australia and New Zealand          7.285000
# Central and Eastern Europe         5.332931
# Eastern Asia                       5.626167
# Latin America and Caribbean        6.144682
# Middle East and Northern Africa    5.406900
# North America                      7.273000
# Southeastern Asia                  5.317444
# Southern Asia                      4.580857
# Sub-Saharan Africa                 4.202800
# Western Europe                     6.689619
# Name: Happiness_score, dtype: float64

# %%
# here we are using boxplot to see happiness_score
plt.figure(figsize=(18,5))
sns.set(style='whitegrid')
sns.boxplot(df['Happiness_score'])
plt.show()

# %%
# here we are seeing box plot of happiness_score of each region
plt.figure(figsize=(18,5))
sns.boxplot(x=df['Region'],y=df['Happiness_score'])
plt.xticks(rotation=75)
plt.show()

# %%
# here we are seeing box plot and swarmplot of  happiness_score of each region
plt.figure(figsize=(18,5))
sns.boxplot(x=df['Region'],y=df['Happiness_score'])
plt.xticks(rotation=75)
sns.swarmplot(x=df['Region'],y=df['Happiness_score'],color=".25")
plt.xticks(rotation=75)
plt.show()

# %%
# here we are seeing swarmplot of each feature
sns.set(style="whitegrid")

sns.swarmplot(y=df["Happiness_score"],color='red')
sns.swarmplot(y=df["Dystopia_residual"],color='blue')
sns.swarmplot(y=df["Economy"],color='yellow')
sns.swarmplot(y=df["Trust"],color='purple')
sns.swarmplot(y=df["Health"],color='green')

plt.title('Happiness_score & Dystopia_residual & Economy  & Trust & Health')
plt.show()

# %%
#counting for each region
sns.countplot(df['Region'])
plt.xticks(rotation=75)
plt.show()

# %%
# disttibution plot of economy
ax = sns.distplot(df['Economy'], rug=True, hist=False)
plt.show()

# %%
# distribution plot of health
ax = sns.distplot(df['Health'], vertical=True)
plt.show()

# %%
# distribution plot of trust
ax = sns.distplot(df['Trust'])
plt.show()

# %%
# distribution plot of family
ax = sns.distplot(df['Family'], color="y")
plt.show()

# %%
df[['Country','Region','Happiness_score']].sort_values(by=['Happiness_score'], ascending=False)
# Out:
#          Country                           Region  Happiness_score
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
# [158 rows x 3 columns]

# %% [markdown]
# # Switzerland in Western Europe has the highest happiness score hence the happiest country while Togo in Sub- Saharan Africa has the lowest Happiness Score and hence the least happy country.

# %%
#Mean of Economy(per GDP) score is 0.8461372151898735.
#Mean of Family score is 0.9910459493670887 
#Mean of Health(Life Expectancy) score is 0.6302593670886076
#Mean of Freedom score is 0.42861493670886075 
#Mean of Trust(Government Corruption) score is 0.14342183544303796
#Mean of Generosity score is 0.2372955063291139
#Mean of Dystopia Residual score is 2.098976772151899

# %%
df[df['Country']=='Switzerland']
# Out:
#        Country          Region  Happiness_rank  Happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
#
#    Standard_error  Economy   Family   Health  Freedom    Trust  Generosity  \
# 0         0.03411  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
#
#    Dystopia_residual
# 0            2.51738

# %%
df[df['Country']=='Togo']
# Out:
#     Country              Region  Happiness_rank  Happiness_score  \
# 157    Togo  Sub-Saharan Africa             158            2.839
#
#      Standard_error  Economy   Family   Health  Freedom    Trust  Generosity  \
# 157         0.06727  0.20868  0.13995  0.28443  0.36453  0.10731     0.16681
#
#      Dystopia_residual
# 157            1.56726

# %%
top5_2015=df[['Country','Happiness_rank', 'Happiness_score']].head()
plt.bar(top5_2015['Country'],top5_2015['Happiness_score'])
for index, value in enumerate(top5_2015['Happiness_score']):
    plt.text(index-0.25,value, str(value))
